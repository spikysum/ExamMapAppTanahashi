# %%
# モジュールのインポート
import pandas as pd
import urllib
import urllib.error
import urllib.request

# Google API モジュール
from pygeocoder import Geocoder
import googlemaps
import pprint

# %%
from gmaps import Geocoding

# %%
key = 'AIzaSyAOKjkkCV0-2ARjPVbfPyPcsUCV__mmMlo'
client = googlemaps.Client(key)

#geocode_result = client.geocode('東京都渋谷駅') # 位置情報を検索
#loc = geocode_result[0]['geometry']['location'] # 軽度・緯度の情報のみ取り出す
loc = (35.68944, 139.69167) #都庁の位置情報
place_result = client.places_nearby(location=loc, radius=200, type='restaurant') #半径200m以内のレストランの情報を取得
pprint.pprint(place_result)
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6908535, 'lng': 139.6912172},
#                            'viewport': {'northeast': {'lat': 35.6923250802915,
#                                                       'lng': 139.6929145802915},
#                                         'southwest': {'lat': 35.6896271197085,
#                                                       'lng': 139.6902166197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Jade Garden',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 336,
#                           'html_attributions': ['<a '
# ...

# %%
import json

with open('./restaurant.json', 'w') as f:
    json.dump(place_result, f, indent=2)

# %%
import urllib.request
import json

url = 'https://petstore.swagger.io/v2/store/order'
req_header = {
    'Content-Type': 'application/json',
}
req_data = json.dumps({
  'id': 0,
  'petId': 0,
  'quantity': 0,
  'shipDate': '2020-04-10T10:11:13.419Z',
  'status': 'placed',
  'complete': True,
})

req = urllib.request.Request(url, data=req_data.encode(), method='POST', headers=req_header)

try:
    with urllib.request.urlopen(req) as response:
        body = json.loads(response.read())
        headers = response.getheaders()
        status = response.getcode()

        print(headers)
        print(status)
        print(body)

except urllib.error.URLError as e:
     print(e.reason)

# %%
curl -X POST -d '{
  "includedTypes": ["restaurant"],
  "maxResultCount": 200,
  "locationRestriction": {
    "circle": {
      "center": {
        "latitude": 37.7937,
        "longitude": -122.3965},
      "radius": 500.0
    }
  }
}' \
-H 'Content-Type: application/json' -H "X-Goog-Api-Key: AIzaSyAOKjkkCV0-2ARjPVbfPyPcsUCV__mmMlo" \
-H "X-Goog-FieldMask: places.displayName" \
https://places.googleapis.com/v1/places:searchNearby

# %%
import requests

headers = {
    'Content-Type': 'application/json',
    'X-Goog-Api-Key': 'AIzaSyAOKjkkCV0-2ARjPVbfPyPcsUCV__mmMlo',
    'X-Goog-FieldMask': 'places.displayName,places.formattedAddress,places.types'
}

json_data = {
    'includedTypes': [
        'restaurant',
    ],
    'maxResultCount': 20,
    'locationRestriction': {
        'circle': {
            'center': {
                'latitude': 35.68944,
                'longitude': 139.69167,
            },
            'radius': 500.0,
        },
    },
}

response = requests.post('https://places.googleapis.com/v1/places:searchNearby', headers=headers, json=json_data)

# %%
with open('./response.txt', mode="wt", encoding="utf-8") as f:
    f.write(response.text)

# %%
response
# Out:
# <Response [200]>

# %%
res_json = response.json()

# %%
res_json
# Out:
# {'places': [{'types': ['department_store',
#     'gift_shop',
#     'cafe',
#     'grocery_store',
#     'sporting_goods_store',
#     'clothing_store',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    'formattedAddress': '5-chōme-24-2 Sendagaya, Shibuya City, Tokyo 151-8580, Japan',
#    'displayName': {'text': 'Takashimaya', 'languageCode': 'en'}},
#   {'types': ['japanese_restaurant',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'formattedAddress': 'Japan, 〒151-0053 Tokyo, Shibuya City, Yoyogi, 2-chōme−20−１６ 相馬ビル １F',
#    'displayName': {'text': 'Udon Shin', 'languageCode': 'en'}},
#   {'types': ['hotel',
#     'banquet_hall',
#     'night_club',
#     'bar',
#     'event_venue',
#     'french_restaurant',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
# ...
