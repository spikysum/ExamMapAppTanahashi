# %%
# モジュールのインポート
import pandas as pd
import urllib
import urllib.error
import urllib.request

# Google API モジュール
from pygeocoder import Geocoder
import googlemaps
import pprint

# %%
from gmaps import Geocoding

# %%
key = 'AIzaSyAOKjkkCV0-2ARjPVbfPyPcsUCV__mmMlo'
client = googlemaps.Client(key)

#geocode_result = client.geocode('東京都渋谷駅') # 位置情報を検索
#loc = geocode_result[0]['geometry']['location'] # 軽度・緯度の情報のみ取り出す
loc = (35.68944, 139.69167) #都庁の位置情報
place_result = client.places_nearby(location=loc, radius=200, typs='restaurant') #半径200m以内のレストランの情報を取得
pprint.pprint(place_result)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AWU5eFj-cGbZnVwwm373xytBkDgKy-7-WkcweKG31a3INgyb8rXJX4Oct07WNWJWF7xp722n_ea13_b_L9w8clnSZ82z_ZOGcRyn95kRgDZmzDkNoh1dKPWCCxS2-blwlpZTr9tn6fbO9RCzP-sybwg5O_3qgSdK5gm79Es0cdfq1mnTjzeKVh_6GToPVjPYIfjbM8OBKbfvKDyavzj-SMgCK0ngC6fQ5L3irU3s6tT4PL_-dxpV3dB7hHbU5YUjtzs0JurrGV7TrZav-DOjtorE9aVwTDuBU715rdf73kKFrc5hCjdOtUNHnLmr7tMKeTFNJ_JVvM_otElaEQDoNDCR8olUV97e8BZuiUHs25W8LN6FlTjpM0xFtuAFGNdBynYR31Hh2l8aZQRyJZBj3uRdGvc00HmC4vvGsfvz-NN4XdnI',
#  'results': [{'geometry': {'location': {'lat': 35.6803997, 'lng': 139.7690174},
#                            'viewport': {'northeast': {'lat': 35.81744534519053,
#                                                       'lng': 139.918874338966},
#                                         'southwest': {'lat': 35.51904202902757,
#                                                       'lng': 139.5628610838164}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Tokyo',
#               'photos': [{'height': 1799,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110543873949960736982">saleem '
#                                                 'zaid</a>'],
#                           'photo_reference': 'AWU5eFhXA3CCk2Afo9uy6F-6LtcnKwyGIXaRyP_N5gSolW5_SAC1bIvtBxznMNVg-X7PO4XGr9XKNZwgkuGVaztDun9Z1wJj3uq7zIf_lu2yf9NQtCs2qFio-WS6RtwG0_vanl4YGTRIg1JrFgkUYkvARzcrpzWMA6Oy4OgirK02UqVQyjnA',
#                           'width': 1080}],
#               'place_id': 'ChIJXSModoWLGGARILWiCfeu2M0',
#               'reference': 'ChIJXSModoWLGGARILWiCfeu2M0',
#               'scope': 'GOOGLE',
#               'types': ['colloquial_area', 'locality', 'political'],
#               'vicinity': 'Tokyo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6908535, 'lng': 139.6912172},
#                            'viewport': {'northeast': {'lat': 35.6923250802915,
#                                                       'lng': 139.6929145802915},
#                                         'southwest': {'lat': 35.6896271197085,
#                                                       'lng': 139.6902166197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Jade Garden',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 336,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108285947907022346614">中国料理「翡翠宮」</a>'],
#                           'photo_reference': 'AWU5eFinBYBDpiKqbT5mpQ2p15lXej5ShlkUAih9xvNCkmUDL9l5GCtZqJaQIabv4pfHeCMgCItq5cdONYAJEVaVqA8wYmgn38e8zV8Rl18sZbQgkNEYE58TptSDZucHWQHVuO6n3bae_h7KJbf2BR5N07Uv06QUSVkGHQShKxpCECJ1Z58',
#                           'width': 448}],
#               'place_id': 'ChIJR3s9zSrzGGARp32UICZCSTM',
#               'plus_code': {'compound_code': 'MMRR+8F Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMRR+8F'},
#               'rating': 4.4,
#               'reference': 'ChIJR3s9zSrzGGARp32UICZCSTM',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 209,
#               'vicinity': '2-chōme-7-2 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6909101, 'lng': 139.6912738},
#                            'viewport': {'northeast': {'lat': 35.69214608029149,
#                                                       'lng': 139.6927830802915},
#                                         'southwest': {'lat': 35.68944811970849,
#                                                       'lng': 139.6900851197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hyatt Regency Tokyo',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1728,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109073215023584649133">ハイアット '
#                                                 'リージェンシー東京</a>'],
#                           'photo_reference': 'AWU5eFgYXBMXCQCFNsZxDSNf3TW2U_IYnq8AKftNMfSu7Xc4dyey5y_0menh85yNZ86sAKJNHN91U1dnU1w-9YZajthpYjG-ZpGUmcdxOKGBk_ReyO-fSQiRR21j2fESXAE2rrhswAfD5P-lJykNcGKjI8Ka-dvfE--jghamrRYG1tL0mX5j',
#                           'width': 2592}],
#               'place_id': 'ChIJR3s9zSrzGGARck5SsvgMA6Q',
#               'plus_code': {'compound_code': 'MMRR+9G Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMRR+9G'},
#               'rating': 4.2,
#               'reference': 'ChIJR3s9zSrzGGARck5SsvgMA6Q',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 5509,
#               'vicinity': '2-chōme-7-2 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6894683, 'lng': 139.6928838},
#                            'viewport': {'northeast': {'lat': 35.6908172802915,
#                                                       'lng': 139.6942327802915},
#                                         'southwest': {'lat': 35.68811931970851,
#                                                       'lng': 139.6915348197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Koga',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110632059050808836154">Kevin '
#                                                 'Wang</a>'],
#                           'photo_reference': 'AWU5eFiIsVFMoHcXluF3XIPUOOXoJ0EUTc_j8mFEpekONOyk2D8mok9yeqXvQhh-81WG2hVxLa1Un0rFLAwayFtndsHopZrFl7PSbXAE6aseBBvRL5N1PTL3zapSmTThcP6NobYr453wW4hxkhuMAs_UNTwcoOvHImBSwdpXdSpQ45eVofyx',
#                           'width': 4032}],
#               'place_id': 'ChIJoTcat9SMGGARuCAumMg0tMI',
#               'plus_code': {'compound_code': 'MMQV+Q5 Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQV+Q5'},
#               'rating': 3.4,
#               'reference': 'ChIJoTcat9SMGGARuCAumMg0tMI',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 39,
#               'vicinity': '2-chōme-8-8-1 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6894807, 'lng': 139.6916863},
#                            'viewport': {'northeast': {'lat': 35.69078314999999,
#                                                       'lng': 139.6935347302915},
#                                         'southwest': {'lat': 35.68698455000001,
#                                                       'lng': 139.6908367697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': 'Tokyo Metropolitan Government Building',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111855112406731253346">Yossy</a>'],
#                           'photo_reference': 'AWU5eFjRHUExPA-5hmJ2-xIbQ_j7plVJ3dNwYvrN6xFSXcpKMUvytm-IpkzGWTTK-97KPzHxzhoa3z_YkS7-nVg6FH-zAjjDipSAArUhlYVMyRjXhq_OeCLY16zC2j2zCRSOvO9IApfPBpMqfkH61-Yu5Y5RjOfZYtyEOeI61ENGg51MzEp0',
#                           'width': 3024}],
#               'place_id': 'ChIJoTcat9SMGGAR6GGG8zdcZvE',
#               'plus_code': {'compound_code': 'MMQR+QM Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+QM'},
#               'rating': 4.4,
#               'reference': 'ChIJoTcat9SMGGAR6GGG8zdcZvE',
#               'scope': 'GOOGLE',
#               'types': ['city_hall',
#                         'tourist_attraction',
#                         'local_government_office',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 4557,
#               'vicinity': '2-chōme-8-1 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6908535, 'lng': 139.6912172},
#                            'viewport': {'northeast': {'lat': 35.6922929302915,
#                                                       'lng': 139.6927684802915},
#                                         'southwest': {'lat': 35.6895949697085,
#                                                       'lng': 139.6900705197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'SPA + WELLNESS Joule （スパ＆ウェルネス「 ジュール」)',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1667,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110818293873389659064">Spa '
#                                                 '+ Wellness Joule （スパ＆ウェルネス「 '
#                                                 'ジュール」)</a>'],
#                           'photo_reference': 'AWU5eFjwAh-zXxTW6IYFk3HGQ9aT8kp_pD-YzVOV9qqusKhmAhxgHO3iOGIpTtPYI3gz_qahGfZnv94gO8jnIPhY0Wy_1QhMEx8H60A8N9RHfs9UZ7nnKM6YzoMseRq4ONWD1roThLzG-bvUNL2MyBaM642YJL0d0GAt73JL74U56tRe2FGZ',
#                           'width': 2500}],
#               'place_id': 'ChIJbSJpzSrzGGARzUjFqX2-bIo',
#               'plus_code': {'compound_code': 'MMRR+8F Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMRR+8F'},
#               'rating': 4.1,
#               'reference': 'ChIJbSJpzSrzGGARzUjFqX2-bIo',
#               'scope': 'GOOGLE',
#               'types': ['beauty_salon',
#                         'spa',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 20,
#               'vicinity': 'ハイアット リージェンシー 東京 ２7F, 2-chōme-7−２ Nishishinjuku, '
#                           'Shinjuku City'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': 35.689733, 'lng': 139.6916563},
#                            'viewport': {'northeast': {'lat': 35.6910434302915,
#                                                       'lng': 139.6931863802915},
#                                         'southwest': {'lat': 35.6883454697085,
#                                                       'lng': 139.6904884197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Tokyo Metropolitan Government Building North '
#                       'Observatory',
#               'permanently_closed': True,
#               'photos': [{'height': 3072,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100864015117825279986">Ryo '
#                                                 'IT</a>'],
#                           'photo_reference': 'AWU5eFgUKVZk3qMeAddjOJuL9_kgceK2_QYpHSAwAmEIej-Xpql5QewKYZFlELGpkpabPfZoNDPBOaLi58Zic9TC8thiOVwGfs7JgG4PGfegdENqp9qpIRlLzwUWKIzRA9gQGMUx4wF2PIfdZLoWtrJpO4LJBhLZv5RUFyzaAsDoTVNEGywn',
#                           'width': 4080}],
#               'place_id': 'ChIJnctryNSMGGARLv4MknPFseU',
#               'plus_code': {'compound_code': 'MMQR+VM Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+VM'},
#               'rating': 4.4,
#               'reference': 'ChIJnctryNSMGGARLv4MknPFseU',
#               'scope': 'GOOGLE',
#               'types': ['tourist_attraction',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5756,
#               'vicinity': '東京都庁第一本庁舎 45F, 2-chōme-8−１ Nishishinjuku, Shinjuku '
#                           'City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6891848, 'lng': 139.6916481},
#                            'viewport': {'northeast': {'lat': 35.6906698802915,
#                                                       'lng': 139.6932020802915},
#                                         'southwest': {'lat': 35.6879719197085,
#                                                       'lng': 139.6905041197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Tokyo Metropolitan Government Building - Tokyo Tourist '
#                       'Information Center',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112680653387850400323">東京観光情報センター東京都庁</a>'],
#                           'photo_reference': 'AWU5eFh3r_q4QL--LWNlnfK2SKgljyubodY0HqaUzzIrYjpPEp_PN6HbHxCaJ-yQ48txxLd47fSUiCqcRwxLKs5vKDKTMLKkD9MD8kTTVCbodPlCWwOYrwpQVj7uPHKZpl4H8zmX43aAprymih6tNLrp8OGeUFOBEFG12g3cGRbvK-kHgdjF',
#                           'width': 2048}],
#               'place_id': 'ChIJoTcat9SMGGARhSXgKSW6QC8',
#               'plus_code': {'compound_code': 'MMQR+MM Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+MM'},
#               'rating': 4.4,
#               'reference': 'ChIJoTcat9SMGGARhSXgKSW6QC8',
#               'scope': 'GOOGLE',
#               'types': ['travel_agency', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 29,
#               'vicinity': '東京都庁第一本庁舎 1階, 2-chōme-8−１ Nishishinjuku, Shinjuku '
#                           'City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.688421, 'lng': 139.6934289},
#                            'viewport': {'northeast': {'lat': 35.69002853029151,
#                                                       'lng': 139.6946791802915},
#                                         'southwest': {'lat': 35.68733056970851,
#                                                       'lng': 139.6919812197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Tonkatsu Ise Shinjuku NS Building',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109912267429293838157">김말똥</a>'],
#                           'photo_reference': 'AWU5eFgXfU9hPkChH2179R9ClPBqBOKBZnV9mGNjQknZfAtyPHyEc5JbhLY7yjmJ96YwY8PdrXO91G0G7ZRHRwpbtHA-S1b7W2ZPpIPCJLk2E4rt-yD80eeNShVhIvKAo3k7dVsl_F-KJvCjTNa5dCTNld9OFB_pbrtTVb4vOo35YruXq_qa',
#                           'width': 1920}],
#               'place_id': 'ChIJXQ4NntOMGGAR1vUDBh1inok',
#               'plus_code': {'compound_code': 'MMQV+99 Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQV+99'},
#               'price_level': 2,
#               'rating': 3.8,
#               'reference': 'ChIJXQ4NntOMGGAR1vUDBh1inok',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 107,
#               'vicinity': '2-chōme-4-1 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6878946, 'lng': 139.6920286},
#                            'viewport': {'northeast': {'lat': 35.6890776802915,
#                                                       'lng': 139.6937474802915},
#                                         'southwest': {'lat': 35.6863797197085,
#                                                       'lng': 139.6910495197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': "Shinjuku Driver's Licence Renewal Center",
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3072,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117100789250969249379">osan '
#                                                 '“69pj69” caps</a>'],
#                           'photo_reference': 'AWU5eFiI6v9DRAktpnx__HT9LINipgcVCPhoRD5W-TASA9WtICom7REL6QbBZ1hCcZ3539DagsX7a9ohXHSwBW9ZNAH-x5zoVu1loW5COb5gVcUZFd1viKu1gODKQzdAm1Peue8RfPly-M4uxTzqQSE9iIDbdIBLeYpoTrCOplxTdNEoeHk_',
#                           'width': 3072}],
#               'place_id': 'ChIJgUGPW9OMGGARWtHcR_4nkqs',
#               'plus_code': {'compound_code': 'MMQR+5R Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+5R'},
#               'rating': 3.6,
#               'reference': 'ChIJgUGPW9OMGGARWtHcR_4nkqs',
#               'scope': 'GOOGLE',
#               'types': ['local_government_office',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 637,
#               'vicinity': '都庁第二本庁舎 2階, 2-chōme-8−１ Nishishinjuku, Shinjuku '
#                           'City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.689187, 'lng': 139.691648},
#                            'viewport': {'northeast': {'lat': 35.6906709802915,
#                                                       'lng': 139.6932020302915},
#                                         'southwest': {'lat': 35.68797301970851,
#                                                       'lng': 139.6905040697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': '東京都都市整備局 都営住宅経営部 指導管理課',
#               'place_id': 'ChIJoTcat9SMGGARsOyc60bt0Xo',
#               'plus_code': {'compound_code': 'MMQR+MM Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+MM'},
#               'reference': 'ChIJoTcat9SMGGARsOyc60bt0Xo',
#               'scope': 'GOOGLE',
#               'types': ['local_government_office',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '2-chōme-8-1 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6910314, 'lng': 139.6909946},
#                            'viewport': {'northeast': {'lat': 35.6923803802915,
#                                                       'lng': 139.6923435802915},
#                                         'southwest': {'lat': 35.6896824197085,
#                                                       'lng': 139.6896456197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'CAFFÈ（カフェ）',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108887262210190048154">CAFFÈ（カフェ）</a>'],
#                           'photo_reference': 'AWU5eFj8FshAOYLuBZ6eWLydxZjzfm85YmXQ_DTT01_vpIgMB60cjMbK02crH2ibuz4h4EZbrLqq_sjIHbYxOzeP-0_SiPd5j5tceqSzHinobRIKEmBd9gvlHD894ZYvSXXyYKTEEitQNfX6LNqD9eDHRQDlp4Y-uWTt2tfR78W2rN8-Snz8',
#                           'width': 1500}],
#               'place_id': 'ChIJDwlszSrzGGARmqnGp_OfS1E',
#               'plus_code': {'compound_code': 'MMRR+C9 Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMRR+C9'},
#               'price_level': 3,
#               'rating': 4.2,
#               'reference': 'ChIJDwlszSrzGGARmqnGp_OfS1E',
#               'scope': 'GOOGLE',
#               'types': ['night_club',
#                         'cafe',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 358,
#               'vicinity': 'ハイアット リージェンシー 東京 (Hyatt Regency Tokyo) '
#                           'ロビーフロア2F\u200e, 2-chōme-7−２ Nishishinjuku, Shinjuku '
#                           'City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6880411, 'lng': 139.6920606},
#                            'viewport': {'northeast': {'lat': 35.6895746302915,
#                                                       'lng': 139.6930215302915},
#                                         'southwest': {'lat': 35.6868766697085,
#                                                       'lng': 139.6903235697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': '東京都住宅政策本部',
#               'photos': [{'height': 2920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117300835067649142275">Paul '
#                                                 '“Riperedtomato”</a>'],
#                           'photo_reference': 'AWU5eFhnveLvC3coV_I-jEsUD5qg6rScD5cgiULZ5rB0xbnDeQDnQPcVcQdyU6eSgWduWvAmL_LKGm4vSYuy2_FpD6AQv4Bhs2GA4os9DZr0vaaWo95-IfM1FXcmawOrCF6RHWzZ5zWjd_8wqlaIm8NAteuFy_IlxGRVzjGVB_c82NOa2Waq',
#                           'width': 5184}],
#               'place_id': 'ChIJoTcat9SMGGARWqAB2wQtkkE',
#               'plus_code': {'compound_code': 'MMQR+6R Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+6R'},
#               'rating': 5,
#               'reference': 'ChIJoTcat9SMGGARWqAB2wQtkkE',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '第二本庁舎, 13階・北, 2-chōme-8−１ Nishishinjuku, Shinjuku '
#                           'City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.690962, 'lng': 139.691059},
#                            'viewport': {'northeast': {'lat': 35.6923109802915,
#                                                       'lng': 139.6924079802915},
#                                         'southwest': {'lat': 35.6896130197085,
#                                                       'lng': 139.6897100197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': '小田急フローリストセンチュリーハイアット作業事務所',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJDwlszSrzGGARtmoJcwxFJjw',
#               'plus_code': {'compound_code': 'MMRR+9C Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMRR+9C'},
#               'reference': 'ChIJDwlszSrzGGARtmoJcwxFJjw',
#               'scope': 'GOOGLE',
#               'types': ['florist',
#                         'store',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '2-chōme-7-2 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6908535, 'lng': 139.6912172},
#                            'viewport': {'northeast': {'lat': 35.6922929302915,
#                                                       'lng': 139.6927684802915},
#                                         'southwest': {'lat': 35.6895949697085,
#                                                       'lng': 139.6900705197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Tanaka Masako Hair Salon',
#               'place_id': 'ChIJCUlPLdWMGGARn7hEJTz3E3s',
#               'plus_code': {'compound_code': 'MMRR+8F Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMRR+8F'},
#               'reference': 'ChIJCUlPLdWMGGARn7hEJTz3E3s',
#               'scope': 'GOOGLE',
#               'types': ['hair_care', 'point_of_interest', 'establishment'],
#               'vicinity': '2-chōme-7-2 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.689187, 'lng': 139.691648},
#                            'viewport': {'northeast': {'lat': 35.6906709802915,
#                                                       'lng': 139.6932020302915},
#                                         'southwest': {'lat': 35.68797301970851,
#                                                       'lng': 139.6905040697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': '東京都港湾局 総務部 総務課',
#               'photos': [{'height': 3264,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112241133587396847317">ty '
#                                                 'De</a>'],
#                           'photo_reference': 'AWU5eFjXZwFcv0-5reQ7HQgN3lO8sF5W6m76bPTq8oAPK3cX6eip80DdvJlRhmbnpoDftu2yT5h3CLmxI3nGqaN25456cpzYn-WffuRHPP_2arNPXGSWTom3ha8xh5ZPttJokXDnjkQ5D20AhY5Z_MwWd03vejxzBGFFz0SllNdEu6dcBwxN',
#                           'width': 1836}],
#               'place_id': 'ChIJoTcat9SMGGARr2Bl9dh0Aow',
#               'plus_code': {'compound_code': 'MMQR+MM Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+MM'},
#               'rating': 3,
#               'reference': 'ChIJoTcat9SMGGARr2Bl9dh0Aow',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '2-chōme-8-1 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.689187, 'lng': 139.691648},
#                            'viewport': {'northeast': {'lat': 35.6906709802915,
#                                                       'lng': 139.6932020302915},
#                                         'southwest': {'lat': 35.68797301970851,
#                                                       'lng': 139.6905040697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': '東京都建設局 公園緑地部 管理課',
#               'place_id': 'ChIJoTcat9SMGGARRsD3BfeKg1k',
#               'plus_code': {'compound_code': 'MMQR+MM Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+MM'},
#               'reference': 'ChIJoTcat9SMGGARRsD3BfeKg1k',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'vicinity': '第二本庁舎, 2-chōme-8−１ Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6895524, 'lng': 139.6931209},
#                            'viewport': {'northeast': {'lat': 35.6909544302915,
#                                                       'lng': 139.6947404802915},
#                                         'southwest': {'lat': 35.6882564697085,
#                                                       'lng': 139.6920425197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Ise Metropolitan Government Office',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101141898025487686716">望月弘</a>'],
#                           'photo_reference': 'AWU5eFgMhPbDGRlRnzGPaFwH9_StJCYv8tyPMOa9bQoZBOiuFmUiF3KJD5rAGqVAytkMJkllz_Ut8EBU7H2Q0YdC5ZLo64wEbuO6DUTtMhAXF5ZeKfknFw4JnNFOZkWsvvWiZVQEWhi6oXeImMwQGpNodoUh7CiDta1uMxAOlS11uIzLp7nG',
#                           'width': 4032}],
#               'place_id': 'ChIJoTcat9SMGGARXdBrwnARzuE',
#               'plus_code': {'compound_code': 'MMQV+R6 Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQV+R6'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJoTcat9SMGGARXdBrwnARzuE',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 106,
#               'vicinity': '2-chōme-8-1 Nishishinjuku, Shinjuku City'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.68948630000001,
#                                         'lng': 139.6917052},
#                            'viewport': {'northeast': {'lat': 35.69086453029151,
#                                                       'lng': 139.6932161302915},
#                                         'southwest': {'lat': 35.68816656970851,
#                                                       'lng': 139.6905181697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': '(株)日本旅行リテイリング 都庁内支店',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJJ4rfudSMGGARgedubBwaIUU',
#               'plus_code': {'compound_code': 'MMQR+QM Shinjuku City, Tokyo, '
#                                              'Japan',
#                             'global_code': '8Q7XMMQR+QM'},
#               'rating': 3.9,
#               'reference': 'ChIJJ4rfudSMGGARgedubBwaIUU',
#               'scope': 'GOOGLE',
#               'types': ['travel_agency', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 7,
#               'vicinity': 'Tokyo Metropolitan Government No.1 Building, １６階 '
#                           '第一本庁舎内, 2-chōme-8−１ Nishishinjuku, Shinjuku City'},
#              {'geometry': {'location': {'lat': 35.6938253, 'lng': 139.7033559},
#                            'viewport': {'northeast': {'lat': 35.72989945846674,
#                                                       'lng': 139.745138558259},
#                                         'southwest': {'lat': 35.67327798164246,
#                                                       'lng': 139.6732557771647}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Shinjuku City',
#               'photos': [{'height': 1188,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118374239741492097900">Ferhat '
#                                                 'Safran</a>'],
#                           'photo_reference': 'AWU5eFh7XdeNrfkiiN1TwIUdZ1r3zyNxQXDB3a4M8hBR4d9Br78ACH3K8fNNuTFeSs-KnuuEvRM8JClu7iRFpIYD7JmxDv4fDDCynzXr157KD420QwYykMhMnEP5Np3jyhrdzJ9tHZOIOs4CpeyP5o_o7gZl19UKH2YIbTuBATw1aNrqci0X',
#                           'width': 1080}],
#               'place_id': 'ChIJS_23WSCNGGAR0u8y4o_GYew',
#               'reference': 'ChIJS_23WSCNGGAR0u8y4o_GYew',
#               'scope': 'GOOGLE',
#               'types': ['locality', 'political'],
#               'vicinity': 'Shinjuku City'}],
#  'status': 'OK'}

# %%
import json

with open('./restaurant.json', 'w') as f:
    json.dump(place_result, f, indent=2)
