# %%
import requests

headers = {
    'Content-Type': 'application/json',
    'X-Goog-Api-Key': 'AIzaSyAOKjkkCV0-2ARjPVbfPyPcsUCV__mmMlo',
    'X-Goog-FieldMask': 'places.types,places.displayName,places.rating,places.location,places.priceLevel,places.formattedAddress,places.nationalPhoneNumber,places.userRatingCount'
}

json_data = {
    'includedTypes': [
        'restaurant',
    ],
    'maxResultCount': 20,
    'locationRestriction': {
        'circle': {
            'center': {
                'latitude': 35.68944,
                'longitude': 139.69167,
            },
            'radius': 500.0,
        },
    },
}

response = requests.post('https://places.googleapis.com/v1/places:searchNearby', headers=headers, json=json_data)

# %%
response.json()
# Out:
# {'places': [{'types': ['restaurant',
#     'spanish_restaurant',
#     'bar',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'nationalPhoneNumber': '03-6300-0174',
#    'formattedAddress': 'Japan, 〒160-0023 Tokyo, Shinjuku City, Nishishinjuku, 4-chōme−31−１ ザ ノット 東京新宿 １階',
#    'location': {'latitude': 35.6882759, 'longitude': 139.6883076},
#    'rating': 4.3,
#    'priceLevel': 'PRICE_LEVEL_MODERATE',
#    'userRatingCount': 551,
#    'displayName': {'text': 'MORETHAN TAPAS LOUNGE', 'languageCode': 'ja'}},
#   {'types': ['seafood_restaurant',
#     'japanese_restaurant',
#     'restaurant',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'nationalPhoneNumber': '03-3343-6622',
#    'formattedAddress': 'Japan, 〒160-0023 Tokyo, Shinjuku City, Nishishinjuku, 3-chōme−2−９ 新宿ワシントンホテル 一階',
#    'location': {'latitude': 35.6867466, 'longitude': 139.693043},
#    'rating': 3.9,
#    'priceLevel': 'PRICE_LEVEL_MODERATE',
# ...

# %%
with open('./response.js', mode="wt", encoding="utf-8") as f:
    f.write(response.text)

# %%
# Out:
# {'places': [{'nationalPhoneNumber': '03-6300-0174',
#    'formattedAddress': 'Japan, 〒160-0023 Tokyo, Shinjuku City, Nishishinjuku, 4-chōme−31−１ ザ ノット 東京新宿 １階',
#    'location': {'latitude': 35.6882759, 'longitude': 139.6883076},
#    'rating': 4.3,
#    'priceLevel': 'PRICE_LEVEL_MODERATE',
#    'userRatingCount': 551,
#    'displayName': {'text': 'MORETHAN TAPAS LOUNGE', 'languageCode': 'ja'}},
#   {'nationalPhoneNumber': '03-3343-6622',
#    'formattedAddress': 'Japan, 〒160-0023 Tokyo, Shinjuku City, Nishishinjuku, 3-chōme−2−９ 新宿ワシントンホテル 一階',
#    'location': {'latitude': 35.6867466, 'longitude': 139.693043},
#    'rating': 3.9,
#    'priceLevel': 'PRICE_LEVEL_MODERATE',
#    'userRatingCount': 1502,
#    'displayName': {'text': 'Zauo Shinjuku', 'languageCode': 'en'}},
#   {'nationalPhoneNumber': '03-6276-7635',
#    'formattedAddress': 'Japan, 〒160-0023 Tokyo, Shinjuku City, Nishishinjuku, 4-chōme−31−１, The Knot Tokyo Shinjuku, 1F',
# ...
